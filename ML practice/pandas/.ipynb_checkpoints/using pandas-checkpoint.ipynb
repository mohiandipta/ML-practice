# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Mohian\OneDrive\Desktop\Exercise\ML practice\pandas/6 class csv.csv")
df
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0               3068          0.002400        0.1700                   16.12
# 1               3042          0.000500        0.1542                   16.60
# 2               2600          0.000300        0.1020                   18.70
# 3               2800          0.000200        0.1600                   16.65
# 4               1939          0.000138        0.1030                   20.06
# ..               ...               ...           ...                     ...
# 235            38940     374830.000000     1356.0000                   -9.93
# 236            30839     834042.000000     1194.0000                  -10.63
# 237             8829     537493.000000     1423.0000                  -10.73
# 238             9235     404940.000000     1112.0000                  -11.23
# 239            37882     294903.000000     1783.0000                   -7.80
#
#      Star type Star color Spectral Class
# ...

# %% [markdown]
# # Check the first 5 rows of the dataset

# %%
# head()
df.head()
# Out:
#    Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0             3068          0.002400        0.1700                   16.12
# 1             3042          0.000500        0.1542                   16.60
# 2             2600          0.000300        0.1020                   18.70
# 3             2800          0.000200        0.1600                   16.65
# 4             1939          0.000138        0.1030                   20.06
#
#    Star type Star color Spectral Class
# 0          0        Red              M
# 1          0        Red              M
# 2          0        Red              M
# 3          0        Red              M
# 4          0        Red              M

# %% [markdown]
# # Check the last 5 rows ot the dataset

# %%
#tail
df.tail()
# Out:
#      Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 235            38940          374830.0        1356.0                   -9.93
# 236            30839          834042.0        1194.0                  -10.63
# 237             8829          537493.0        1423.0                  -10.73
# 238             9235          404940.0        1112.0                  -11.23
# 239            37882          294903.0        1783.0                   -7.80
#
#      Star type Star color Spectral Class
# 235          5       Blue              O
# 236          5       Blue              O
# 237          5      White              A
# 238          5      White              A
# 239          5       Blue              O

# %% [markdown]
# # Any rows from the dataset using range ex: 20:35

# %%
df[20:36]
# Out:
#     Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 20            25000          0.056000       0.00840                   10.58
# 21             7740          0.000490       0.01234                   14.02
# 22             7220          0.000170       0.01100                   14.23
# 23             8500          0.000500       0.01000                   14.50
# 24            16500          0.013000       0.01400                   11.89
# 25            12990          0.000085       0.00984                   12.23
# 26             8570          0.000810       0.00970                   14.20
# 27             7700          0.000110       0.01280                   14.47
# 28            11790          0.000150       0.01100                   12.59
# 29             7230          0.000080       0.01300                   14.08
# 30            39000     204000.000000      10.60000                   -4.70
# ...

# %% [markdown]
# # Check the Information of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Temperature (K)         240 non-null    int64
#  1   Luminosity(L/Lo)        240 non-null    float64
#  2   Radius(R/Ro)            240 non-null    float64
#  3   Absolute magnitude(Mv)  240 non-null    float64
#  4   Star type               240 non-null    int64
#  5   Star color              240 non-null    object
#  6   Spectral Class          240 non-null    object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 13.2+ KB

# %% [markdown]
# # Check the description of the data

# %%
df.describe()
#df.describe(include = "all")
# Out:
#        Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  \
# count       240.000000        240.000000    240.000000
# mean      10497.462500     107188.361635    237.157781
# std        9552.425037     179432.244940    517.155763
# min        1939.000000          0.000080      0.008400
# 25%        3344.250000          0.000865      0.102750
# 50%        5776.000000          0.070500      0.762500
# 75%       15055.500000     198050.000000     42.750000
# max       40000.000000     849420.000000   1948.500000
#
#        Absolute magnitude(Mv)   Star type
# count              240.000000  240.000000
# mean                 4.382396    2.500000
# std                 10.532512    1.711394
# min                -11.920000    0.000000
# 25%                 -6.232500    1.000000
# 50%                  8.313000    2.500000
# 75%                 13.697500    4.000000
# max                 20.060000    5.000000

# %% [markdown]
# # check the name of the columns in the dataset

# %%
df.columns
# Out:
# Index(['Temperature (K)', 'Luminosity(L/Lo)', 'Radius(R/Ro)',
#        'Absolute magnitude(Mv)', 'Star type', 'Star color', 'Spectral Class'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['Temperature (K)',
#  'Luminosity(L/Lo)',
#  'Radius(R/Ro)',
#  'Absolute magnitude(Mv)',
#  'Star type',
#  'Star color',
#  'Spectral Class']

# %%
for i in df.columns:
    print(i)
# Out:
# Temperature (K)
# Luminosity(L/Lo)
# Radius(R/Ro)
# Absolute magnitude(Mv)
# Star type
# Star color
# Spectral Class

# %% [markdown]
# # Check the number of the number of the Class under the Spectral Class column in the dataset

# %%
df.groupby(['Spectral Class']).size()
# Out:
# Spectral Class
# A     19
# B     46
# F     17
# G      1
# K      6
# M    111
# O     40
# dtype: int64

# %% [markdown]
# # Check for the missing value from the dataset

# %%
# df.isnull()
# df.isnull().values.any()
df.isnull().sum()
# Out:
# Temperature (K)           0
# Luminosity(L/Lo)          0
# Radius(R/Ro)              0
# Absolute magnitude(Mv)    0
# Star type                 0
# Star color                0
# Spectral Class            0
# dtype: int64
